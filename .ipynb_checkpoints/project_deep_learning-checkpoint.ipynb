# %%
# !pip install kaggle
# !pip install pandas
# !pip install scikit-learn
# !pip install matplotlib
# !pip install tensorflow
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.6.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.6.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization, Activation
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.models import Sequential, load_model
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import json
import ast
import os

print("\n","Tensorflow version " + tf.__version__)
# Out:
#  Tensorflow version 2.15.0

# %%
os.environ['KAGGLE_USERNAME'] = "antoineguines"
os.environ['KAGGLE_KEY'] = "763e4e8c48ce54809476f469031bd265"

# !mkdir model
# !mkdir dataframe
# !kaggle datasets download -d gsimonx37/letterboxd
# !unzip letterboxd.zip
# !rm actors.csv countries.csv crew.csv languages.csv movies.csv releases.csv studios.csv themes.csv
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: posters/1883123.jpg
#   inflating: posters/1883132.jpg
#   inflating: posters/1883133.jpg
#   inflating: posters/1883144.jpg
#   inflating: posters/1883145.jpg
#   inflating: posters/1883146.jpg
#   inflating: posters/1883148.jpg
#   inflating: posters/1883155.jpg
#   inflating: posters/1883156.jpg
#   inflating: posters/1883159.jpg
#   inflating: posters/1883161.jpg
#   inflating: posters/1883162.jpg
#   inflating: posters/1883167.jpg
#   inflating: posters/1883169.jpg
#   inflating: posters/1883175.jpg
#   inflating: posters/1883180.jpg
#   inflating: posters/1883184.jpg
#   inflating: posters/1883185.jpg
#   inflating: posters/1883188.jpg
#   inflating: posters/1883190.jpg
#   inflating: posters/1883191.jpg
#   inflating: posters/1883196.jpg
#   inflating: posters/1883202.jpg
#   inflating: posters/1883207.jpg
#   inflating: posters/1883213.jpg
#   inflating: posters/1883214.jpg
#   inflating: posters/1883217.jpg
#   inflating: posters/1883218.jpg
#   inflating: posters/1883223.jpg
#   inflating: posters/1883224.jpg
#   inflating: posters/1883226.jpg
#   inflating: posters/1883229.jpg
#   inflating: posters/1883233.jpg
#   inflating: posters/1883236.jpg
#   inflating: posters/1883239.jpg
#   inflating: posters/1883240.jpg
#   inflating: posters/1883242.jpg
#   inflating: posters/1883243.jpg
#   inflating: posters/1883247.jpg
#   inflating: posters/1883252.jpg
#   inflating: posters/1883257.jpg
#   inflating: posters/1883260.jpg
#   inflating: posters/1883268.jpg
#   inflating: posters/1883271.jpg
#   inflating: posters/1883272.jpg
#   inflating: posters/1883273.jpg
#   inflating: posters/1883274.jpg
#   inflating: posters/1883275.jpg
#   inflating: posters/1883276.jpg
#   inflating: posters/1883277.jpg
#   inflating: posters/1883278.jpg
#   inflating: posters/1883279.jpg
#   inflating: posters/1883281.jpg
#   inflating: posters/1883282.jpg
#   inflating: posters/1883283.jpg
#   inflating: posters/1883284.jpg
#   inflating: posters/1883286.jpg
#   inflating: posters/1883287.jpg
#   inflating: posters/1883288.jpg
#   inflating: posters/1883289.jpg
#   inflating: posters/1883290.jpg
#   inflating: posters/1883291.jpg
#   inflating: posters/1883292.jpg
#   inflating: posters/1883293.jpg
#   inflating: posters/1883294.jpg
#   inflating: posters/1883295.jpg
#   inflating: posters/1883296.jpg
#   inflating: posters/1883297.jpg
#   inflating: posters/1883302.jpg
#   inflating: posters/1883303.jpg
#   inflating: posters/1883306.jpg
#   inflating: posters/1883309.jpg
#   inflating: posters/1883312.jpg
#   inflating: posters/1883313.jpg
#   inflating: posters/1883316.jpg
#   inflating: posters/1883317.jpg
#   inflating: posters/1883323.jpg
#   inflating: posters/1883325.jpg
#   inflating: posters/1883328.jpg
#   inflating: posters/1883330.jpg
#   inflating: posters/1883331.jpg
#   inflating: posters/1883332.jpg
#   inflating: posters/1883334.jpg
#   inflating: posters/1883337.jpg
#   inflating: posters/1883340.jpg
#   inflating: posters/1883346.jpg
#   inflating: posters/1883348.jpg
#   inflating: posters/1883349.jpg
#   inflating: posters/1883350.jpg
#   inflating: posters/1883354.jpg
#   inflating: posters/1883355.jpg
#   inflating: posters/1883358.jpg
#   inflating: posters/1883359.jpg
#   inflating: posters/1883363.jpg
#   inflating: posters/1883366.jpg
#   inflating: posters/1883368.jpg
#   inflating: posters/1883372.jpg
#   inflating: posters/1883376.jpg
#   inflating: posters/1883379.jpg
#   inflating: posters/1883387.jpg
#   inflating: posters/1883388.jpg
#   inflating: posters/1883397.jpg
#   inflating: posters/1883402.jpg
#   inflating: posters/1883403.jpg
#   inflating: posters/1883405.jpg
#   inflating: posters/1883406.jpg
#   inflating: posters/1883407.jpg
#   inflating: posters/1883410.jpg
#   inflating: posters/1883417.jpg
#   inflating: posters/1883420.jpg
#   inflating: posters/1883425.jpg
#   inflating: posters/1883433.jpg
#   inflating: posters/1883435.jpg
#   inflating: posters/1883438.jpg
#   inflating: posters/1883440.jpg
#   inflating: posters/1883441.jpg
#   inflating: posters/1883443.jpg
#   inflating: posters/1883444.jpg
#   inflating: posters/1883447.jpg
#   inflating: posters/1883449.jpg
#   inflating: posters/1883450.jpg
#   inflating: posters/1883451.jpg
#   inflating: posters/1883453.jpg
#   inflating: posters/1883455.jpg
#   inflating: posters/1883457.jpg
#   inflating: posters/1883458.jpg
#   inflating: posters/1883459.jpg
#   inflating: posters/1883461.jpg
#   inflating: posters/1883467.jpg
#   inflating: posters/1883468.jpg
#   inflating: posters/1883477.jpg
#   inflating: posters/1883482.jpg
#   inflating: posters/1883483.jpg
#   inflating: posters/1883493.jpg
#   inflating: posters/1883496.jpg
#   inflating: posters/1883497.jpg
#   inflating: posters/1883499.jpg
#   inflating: posters/1883503.jpg
#   inflating: posters/1883504.jpg
#   inflating: posters/1883506.jpg
#   inflating: posters/1883513.jpg
#   inflating: posters/1883517.jpg
#   inflating: posters/1883520.jpg
#   inflating: posters/1883521.jpg
#   inflating: posters/1883522.jpg
#   inflating: posters/1883530.jpg
#   inflating: posters/1883536.jpg
#   inflating: posters/1883539.jpg
#   inflating: posters/1883541.jpg
#   inflating: posters/1883543.jpg
#   inflating: posters/1883551.jpg
#   inflating: posters/1883554.jpg
#   inflating: posters/1883566.jpg
#   inflating: posters/1883572.jpg
#   inflating: posters/1883577.jpg
#   inflating: posters/1883582.jpg
#   inflating: posters/1883583.jpg
#   inflating: posters/1883584.jpg
#   inflating: posters/1883585.jpg
#   inflating: posters/1883586.jpg
#   inflating: posters/1883590.jpg
#   inflating: posters/1883594.jpg
#   inflating: posters/1883602.jpg
#   inflating: posters/1883605.jpg
#   inflating: posters/1883608.jpg
#   inflating: posters/1883609.jpg
#   inflating: posters/1883616.jpg
#   inflating: posters/1883617.jpg
#   inflating: posters/1883621.jpg
#   inflating: posters/1883632.jpg
#   inflating: posters/1883636.jpg
#   inflating: posters/1883639.jpg
#   inflating: posters/1883641.jpg
#   inflating: posters/1883643.jpg
#   inflating: posters/1883648.jpg
#   inflating: posters/1883651.jpg
#   inflating: posters/1883654.jpg
#   inflating: posters/1883659.jpg
#   inflating: posters/1883661.jpg
#   inflating: posters/1883662.jpg
#   inflating: posters/1883665.jpg
#   inflating: posters/1883667.jpg
#   inflating: posters/1883672.jpg
#   inflating: posters/1883679.jpg
#   inflating: posters/1883680.jpg
#   inflating: posters/1883681.jpg
#   inflating: posters/1883684.jpg
#   inflating: posters/1883685.jpg
#   inflating: posters/1883686.jpg
#   inflating: posters/1883687.jpg
#   inflating: posters/1883688.jpg
#   inflating: posters/1883705.jpg
#   inflating: posters/1883706.jpg
#   inflating: posters/1883707.jpg
#   inflating: posters/1883709.jpg
#   inflating: posters/1883711.jpg
#   inflating: posters/1883712.jpg
#   inflating: posters/1883713.jpg
#   inflating: posters/1883714.jpg
#   inflating: posters/1883715.jpg
#   inflating: posters/1883717.jpg
#   inflating: posters/1883718.jpg
#   inflating: posters/1883724.jpg
#   inflating: posters/1883725.jpg
#   inflating: posters/1883727.jpg
#   inflating: posters/1883731.jpg
#   inflating: posters/1883733.jpg
#   inflating: posters/1883735.jpg
#   inflating: posters/1883736.jpg
#   inflating: posters/1883738.jpg
#   inflating: posters/1883740.jpg
#   inflating: posters/1883741.jpg
#   inflating: posters/1883743.jpg
#   inflating: posters/1883744.jpg
#   inflating: posters/1883745.jpg
#   inflating: posters/1883768.jpg
#   inflating: posters/1883769.jpg
#   inflating: posters/1883770.jpg
#   inflating: posters/1883777.jpg
#   inflating: posters/1883781.jpg
#   inflating: posters/1883782.jpg
#   inflating: posters/1883789.jpg
#   inflating: posters/1883790.jpg
#   inflating: posters/1883794.jpg
#   inflating: posters/1883804.jpg
#   inflating: posters/1883805.jpg
#   inflating: posters/1883807.jpg
#   inflating: posters/1883808.jpg
#   inflating: posters/1883811.jpg
#   inflating: posters/1883812.jpg
#   inflating: posters/1883814.jpg
#   inflating: posters/1883827.jpg
#   inflating: posters/1883828.jpg
#   inflating: posters/1883829.jpg
#   inflating: posters/1883834.jpg
#   inflating: posters/1883835.jpg
#   inflating: posters/1883836.jpg
#   inflating: posters/1883837.jpg
#   inflating: posters/1883838.jpg
#   inflating: posters/1883839.jpg
#   inflating: posters/1883840.jpg
#   inflating: posters/1883843.jpg
#   inflating: posters/1883847.jpg
#   inflating: posters/1883867.jpg
#   inflating: posters/1883873.jpg
#   inflating: posters/1883875.jpg
#   inflating: posters/1883876.jpg
#   inflating: posters/1883877.jpg
#   inflating: posters/1883879.jpg
#   inflating: posters/1883881.jpg
#   inflating: posters/1883882.jpg
#   inflating: posters/1883885.jpg
#   inflating: posters/1883889.jpg
#   inflating: posters/1883890.jpg
#   inflating: posters/1883895.jpg
#   inflating: posters/1883896.jpg
#   inflating: posters/1883898.jpg
#   inflating: posters/1883905.jpg
#   inflating: posters/1883907.jpg
#   inflating: posters/1883917.jpg
#   inflating: posters/1883920.jpg
#   inflating: posters/1883923.jpg
#   inflating: posters/1883924.jpg
#   inflating: posters/1883928.jpg
#   inflating: posters/1883930.jpg
#   inflating: posters/1883935.jpg
#   inflating: posters/1883936.jpg
#   inflating: posters/1883941.jpg
#   inflating: posters/1883944.jpg
#   inflating: posters/1883945.jpg
#   inflating: posters/1883946.jpg
#   inflating: posters/1883948.jpg
#   inflating: posters/1883950.jpg
#   inflating: posters/1883951.jpg
#   inflating: posters/1883953.jpg
#   inflating: posters/1883962.jpg
#   inflating: posters/1883967.jpg
#   inflating: posters/1883975.jpg
#   inflating: posters/1883981.jpg
#   inflating: posters/1883982.jpg
#   inflating: posters/1883983.jpg
#   inflating: posters/1883984.jpg
#   inflating: posters/1883989.jpg
#   inflating: posters/1883990.jpg
#   inflating: posters/1883992.jpg
#   inflating: posters/1883994.jpg
#   inflating: posters/1883996.jpg
#   inflating: posters/1883997.jpg
#   inflating: posters/1883999.jpg
#   inflating: posters/1884001.jpg
#   inflating: posters/1884003.jpg
#   inflating: posters/1884005.jpg
#   inflating: posters/1884007.jpg
#   inflating: posters/1884011.jpg
#   inflating: posters/1884013.jpg
#   inflating: posters/1884014.jpg
#   inflating: posters/1884015.jpg
#   inflating: posters/1884017.jpg
#   inflating: posters/1884018.jpg
#   inflating: posters/1884020.jpg
#   inflating: posters/1884021.jpg
#   inflating: posters/1884026.jpg
#   inflating: posters/1884030.jpg
#   inflating: posters/1884037.jpg
#   inflating: posters/1884039.jpg
#   inflating: posters/1884042.jpg
#   inflating: posters/1884043.jpg
#   inflating: posters/1884047.jpg
#   inflating: posters/1884048.jpg
#   inflating: posters/1884057.jpg
#   inflating: posters/1884058.jpg
#   inflating: posters/1884062.jpg
#   inflating: posters/1884069.jpg
#   inflating: posters/1884073.jpg
#   inflating: posters/1884074.jpg
#   inflating: posters/1884080.jpg
#   inflating: posters/1884085.jpg
#   inflating: posters/1884092.jpg
#   inflating: posters/1884093.jpg
#   inflating: posters/1884095.jpg
#   inflating: posters/1884100.jpg
#   inflating: posters/1884104.jpg
#   inflating: posters/1884113.jpg
#   inflating: posters/1884114.jpg
#   inflating: posters/1884117.jpg
#   inflating: posters/1884118.jpg
#   inflating: posters/1884119.jpg
#   inflating: posters/1884126.jpg
#   inflating: posters/1884128.jpg
#   inflating: posters/1884134.jpg
#   inflating: posters/1884136.jpg
#   inflating: posters/1884139.jpg
#   inflating: posters/1884148.jpg
#   inflating: posters/1884149.jpg
#   inflating: posters/1884150.jpg
#   inflating: posters/1884155.jpg
#   inflating: posters/1884170.jpg
#   inflating: posters/1884172.jpg
#   inflating: posters/1884173.jpg
#   inflating: posters/1884175.jpg
#   inflating: posters/1884177.jpg
#   inflating: posters/1884183.jpg
#   inflating: posters/1884184.jpg
#   inflating: posters/1884185.jpg
#   inflating: posters/1884187.jpg
#   inflating: posters/1884194.jpg
#   inflating: posters/1884196.jpg
#   inflating: posters/1884199.jpg
#   inflating: posters/1884200.jpg
#   inflating: posters/1884203.jpg
#   inflating: posters/1884214.jpg
#   inflating: posters/1884216.jpg
#   inflating: posters/1884217.jpg
#   inflating: posters/1884218.jpg
#   inflating: posters/1884220.jpg
#   inflating: posters/1884223.jpg
#   inflating: posters/1884241.jpg
#   inflating: posters/1884243.jpg
#   inflating: posters/1884246.jpg
#   inflating: posters/1884250.jpg
#   inflating: posters/1884259.jpg
#   inflating: posters/1884267.jpg
#   inflating: posters/1884270.jpg
#   inflating: posters/1884273.jpg
#   inflating: posters/1884275.jpg
#   inflating: posters/1884280.jpg
#   inflating: posters/1884283.jpg
#   inflating: posters/1884286.jpg
#   inflating: posters/1884287.jpg
#   inflating: posters/1884288.jpg
#   inflating: posters/1884289.jpg
#   inflating: posters/1884294.jpg
#   inflating: posters/1884295.jpg
#   inflating: posters/1884301.jpg
#   inflating: posters/1884302.jpg
#   inflating: posters/1884304.jpg
#   inflating: posters/1884308.jpg
#   inflating: posters/1884310.jpg
#   inflating: posters/1884313.jpg
#   inflating: posters/1884314.jpg
#   inflating: posters/1884315.jpg
#   inflating: posters/1884317.jpg
#   inflating: posters/1884321.jpg
#   inflating: posters/1884323.jpg
#   inflating: posters/1884324.jpg
#   inflating: posters/1884332.jpg
#   inflating: posters/1884337.jpg
#   inflating: posters/1884340.jpg
#   inflating: posters/1884341.jpg
#   inflating: posters/1884344.jpg
#   inflating: posters/1884348.jpg
#   inflating: posters/1884352.jpg
#   inflating: posters/1884353.jpg
#   inflating: posters/1884355.jpg
#   inflating: posters/1884356.jpg
#   inflating: posters/1884360.jpg
#   inflating: posters/1884361.jpg
#   inflating: posters/1884362.jpg
#   inflating: posters/1884366.jpg
#   inflating: posters/1884371.jpg
#   inflating: posters/1884376.jpg
#   inflating: posters/1884392.jpg
#   inflating: posters/1884393.jpg
#   inflating: posters/1884398.jpg
#   inflating: posters/1884400.jpg
#   inflating: posters/1884401.jpg
#   inflating: posters/1884410.jpg
#   inflating: posters/1884412.jpg
#   inflating: posters/1884413.jpg
#   inflating: posters/1884414.jpg
#   inflating: posters/1884415.jpg
#   inflating: posters/1884416.jpg
#   inflating: posters/1884417.jpg
#   inflating: posters/1884419.jpg
#   inflating: posters/1884420.jpg
#   inflating: posters/1884426.jpg
#   inflating: posters/1884429.jpg
#   inflating: posters/1884434.jpg
#   inflating: posters/1884436.jpg
#   inflating: posters/1884449.jpg
#   inflating: posters/1884453.jpg
#   inflating: posters/1884454.jpg
#   inflating: posters/1884455.jpg
#   inflating: posters/1884456.jpg
#   inflating: posters/1884457.jpg
#   inflating: posters/1884458.jpg
#   inflating: posters/1884460.jpg
#   inflating: posters/1884461.jpg
#   inflating: posters/1884464.jpg
#   inflating: posters/1884465.jpg
#   inflating: posters/1884470.jpg
#   inflating: posters/1884475.jpg
#   inflating: posters/1884477.jpg
#   inflating: posters/1884486.jpg
#   inflating: posters/1884501.jpg
#   inflating: posters/1884502.jpg
#   inflating: posters/1884506.jpg
#   inflating: posters/1884511.jpg
#   inflating: posters/1884512.jpg
#   inflating: posters/1884513.jpg
#   inflating: posters/1884518.jpg
#   inflating: posters/1884519.jpg
#   inflating: posters/1884520.jpg
#   inflating: posters/1884521.jpg
#   inflating: posters/1884522.jpg
#   inflating: posters/1884526.jpg
#   inflating: posters/1884527.jpg
#   inflating: posters/1884530.jpg
#   inflating: posters/1884532.jpg
#   inflating: posters/1884543.jpg
#   inflating: posters/1884547.jpg
#   inflating: posters/1884549.jpg
#   inflating: posters/1884551.jpg
#   inflating: posters/1884552.jpg
#   inflating: posters/1884553.jpg
#   inflating: posters/1884557.jpg
#   inflating: posters/1884560.jpg
#   inflating: posters/1884562.jpg
#   inflating: posters/1884563.jpg
#   inflating: posters/1884565.jpg
#   inflating: posters/1884568.jpg
#   inflating: posters/1884569.jpg
#   inflating: posters/1884570.jpg
#   inflating: posters/1884574.jpg
#   inflating: posters/1884575.jpg
#   inflating: posters/1884580.jpg
#   inflating: posters/1884582.jpg
#   inflating: posters/1884584.jpg
#   inflating: posters/1884594.jpg
#   inflating: posters/1884595.jpg
#   inflating: posters/1884600.jpg
#   inflating: posters/1884605.jpg
#   inflating: posters/1884615.jpg
#   inflating: posters/1884616.jpg
#   inflating: posters/1884617.jpg
#   inflating: posters/1884618.jpg
#   inflating: posters/1884624.jpg
#   inflating: posters/1884625.jpg
#   inflating: posters/1884633.jpg
#   inflating: posters/1884636.jpg
#   inflating: posters/1884637.jpg
#   inflating: posters/1884642.jpg
#   inflating: posters/1884645.jpg
#   inflating: posters/1884649.jpg
#   inflating: posters/1884655.jpg
#   inflating: posters/1884656.jpg
#   inflating: posters/1884658.jpg
#   inflating: posters/1884660.jpg
#   inflating: posters/1884661.jpg
#   inflating: posters/1884664.jpg
#   inflating: posters/1884665.jpg
#   inflating: posters/1884673.jpg
#   inflating: posters/1884675.jpg
#   inflating: posters/1884677.jpg
#   inflating: posters/1884679.jpg
#   inflating: posters/1884682.jpg
#   inflating: posters/1884683.jpg
#   inflating: posters/1884686.jpg
#   inflating: posters/1884687.jpg
#   inflating: posters/1884688.jpg
#   inflating: posters/1884689.jpg
#   inflating: posters/1884691.jpg
#   inflating: posters/1884693.jpg
#   inflating: posters/1884695.jpg
#   inflating: posters/1884701.jpg
#   inflating: posters/1884702.jpg
#   inflating: posters/1884703.jpg
#   inflating: posters/1884705.jpg
#   inflating: posters/1884711.jpg
#   inflating: posters/1884719.jpg
#   inflating: posters/1884721.jpg
#   inflating: posters/1884722.jpg
#   inflating: posters/1884723.jpg
#   inflating: posters/1884725.jpg
#   inflating: posters/1884727.jpg
#   inflating: posters/1884729.jpg
#   inflating: posters/1884730.jpg
#   inflating: posters/1884734.jpg
#   inflating: posters/1884740.jpg
#   inflating: posters/1884743.jpg
#   inflating: posters/1884744.jpg
#   inflating: posters/1884747.jpg
#   inflating: posters/1884748.jpg
#   inflating: posters/1884752.jpg
#   inflating: posters/1884754.jpg
#   inflating: posters/1884755.jpg
#   inflating: posters/1884757.jpg
#   inflating: posters/1884760.jpg
#   inflating: posters/1884762.jpg
#   inflating: posters/1884763.jpg
#   inflating: posters/1884772.jpg
#   inflating: posters/1884776.jpg
#   inflating: posters/1884780.jpg
#   inflating: posters/1884786.jpg
#   inflating: posters/1884798.jpg
#   inflating: posters/1884805.jpg
#   inflating: posters/1884808.jpg
#   inflating: posters/1884810.jpg
#   inflating: posters/1884817.jpg
#   inflating: posters/1884823.jpg
#   inflating: posters/1884826.jpg
#   inflating: posters/1884833.jpg
#   inflating: posters/1884834.jpg
#   inflating: posters/1884843.jpg
#   inflating: posters/1884844.jpg
#   inflating: posters/1884857.jpg
#   inflating: posters/1884858.jpg
#   inflating: posters/1884868.jpg
#   inflating: posters/1884874.jpg
#   inflating: posters/1884875.jpg
#   inflating: posters/1884882.jpg
#   inflating: posters/1884883.jpg
#   inflating: posters/1884886.jpg
#   inflating: posters/1884893.jpg
#   inflating: posters/1884902.jpg
#   inflating: posters/1884903.jpg
#   inflating: posters/1884904.jpg
#   inflating: posters/1884906.jpg
#   inflating: posters/1884907.jpg
#   inflating: posters/1884908.jpg
#   inflating: posters/1884911.jpg
#   inflating: posters/1884915.jpg
#   inflating: posters/1884922.jpg
#   inflating: posters/1884923.jpg
#   inflating: posters/1884924.jpg
#   inflating: posters/1884925.jpg
#   inflating: posters/1884929.jpg
#   inflating: posters/1884936.jpg
#   inflating: posters/1884937.jpg
#   inflating: posters/1884940.jpg
#   inflating: posters/1884943.jpg
#   inflating: posters/1884945.jpg
#   inflating: posters/1884952.jpg
#   inflating: posters/1884953.jpg
#   inflating: posters/1884960.jpg
#   inflating: posters/1884964.jpg
#   inflating: posters/1884968.jpg
#   inflating: posters/1884969.jpg
#   inflating: posters/1884970.jpg
#   inflating: posters/1884971.jpg
#   inflating: posters/1884975.jpg
#   inflating: posters/1884976.jpg
#   inflating: posters/1884978.jpg
#   inflating: posters/1884979.jpg
#   inflating: posters/1884984.jpg
#   inflating: posters/1884989.jpg
#   inflating: posters/1884992.jpg
#   inflating: posters/1884993.jpg
#   inflating: posters/1884997.jpg
#   inflating: posters/1884998.jpg
#   inflating: posters/1885000.jpg
#   inflating: posters/1885001.jpg
#   inflating: posters/1885017.jpg
#   inflating: posters/1885018.jpg
#   inflating: posters/1885021.jpg
#   inflating: posters/1885022.jpg
#   inflating: posters/1885023.jpg
#   inflating: posters/1885024.jpg
#   inflating: posters/1885025.jpg
#   inflating: posters/1885033.jpg
#   inflating: posters/1885034.jpg
#   inflating: posters/1885036.jpg
#   inflating: posters/1885049.jpg
#   inflating: posters/1885052.jpg
#   inflating: posters/1885053.jpg
#   inflating: posters/1885058.jpg
#   inflating: posters/1885059.jpg
#   inflating: posters/1885060.jpg
#   inflating: posters/1885061.jpg
#   inflating: posters/1885068.jpg
#   inflating: posters/1885070.jpg
#   inflating: posters/1885078.jpg
#   inflating: posters/1885086.jpg
#   inflating: posters/1885088.jpg
#   inflating: posters/1885092.jpg
#   inflating: posters/1885093.jpg
#   inflating: posters/1885097.jpg
#   inflating: posters/1885099.jpg
#   inflating: posters/1885100.jpg
#   inflating: posters/1885101.jpg
#   inflating: posters/1885102.jpg
#   inflating: posters/1885114.jpg
#   inflating: posters/1885117.jpg
#   inflating: posters/1885121.jpg
#   inflating: posters/1885125.jpg
#   inflating: posters/1885128.jpg
#   inflating: posters/1885130.jpg
#   inflating: posters/1885131.jpg
#   inflating: posters/1885135.jpg
#   inflating: posters/1885142.jpg
#   inflating: posters/1885143.jpg
#   inflating: posters/1885150.jpg
#   inflating: posters/1885163.jpg
#   inflating: posters/1885167.jpg
#   inflating: posters/1885175.jpg
#   inflating: posters/1885176.jpg
#   inflating: posters/1885199.jpg
#   inflating: posters/1885215.jpg
#   inflating: posters/1885224.jpg
#   inflating: posters/1885233.jpg
#   inflating: posters/1885236.jpg
#   inflating: posters/1885237.jpg
#   inflating: posters/1885239.jpg
#   inflating: posters/1885244.jpg
#   inflating: posters/1885246.jpg
#   inflating: posters/1885252.jpg
#   inflating: posters/1885255.jpg
#   inflating: posters/1885261.jpg
#   inflating: posters/1885262.jpg
#   inflating: posters/1885264.jpg
#   inflating: posters/1885266.jpg
#   inflating: posters/1885268.jpg
#   inflating: posters/1885271.jpg
#   inflating: posters/1885272.jpg
#   inflating: posters/1885288.jpg
#   inflating: posters/1885292.jpg
#   inflating: posters/1885293.jpg
#   inflating: posters/1885294.jpg
#   inflating: posters/1885295.jpg
#   inflating: posters/1885305.jpg
#   inflating: posters/1885315.jpg
#   inflating: posters/1885321.jpg
#   inflating: posters/1885328.jpg
#   inflating: posters/1885329.jpg
#   inflating: posters/1885332.jpg
#   inflating: posters/1885335.jpg
#   inflating: posters/1885338.jpg
#   inflating: posters/1885340.jpg
#   inflating: posters/1885341.jpg
#   inflating: posters/1885347.jpg
#   inflating: posters/1885348.jpg
#   inflating: posters/1885349.jpg
#   inflating: posters/1885350.jpg
#   inflating: posters/1885354.jpg
#   inflating: posters/1885357.jpg
#   inflating: posters/1885364.jpg
#   inflating: posters/1885365.jpg
#   inflating: posters/1885371.jpg
#   inflating: posters/1885374.jpg
#   inflating: posters/1885380.jpg
#   inflating: posters/1885388.jpg
#   inflating: posters/1885389.jpg
#   inflating: posters/1885391.jpg
#   inflating: posters/1885392.jpg
#   inflating: posters/1885393.jpg
#   inflating: posters/1885394.jpg
#   inflating: posters/1885395.jpg
#   inflating: posters/1885398.jpg
#   inflating: posters/1885401.jpg
#   inflating: posters/1885407.jpg
#   inflating: posters/1885410.jpg
#   inflating: posters/1885414.jpg
#   inflating: posters/1885417.jpg
#   inflating: posters/1885418.jpg
#   inflating: posters/1885419.jpg
#   inflating: posters/1885423.jpg
#   inflating: posters/1885425.jpg
#   inflating: posters/1885427.jpg
#   inflating: posters/1885435.jpg
#   inflating: posters/1885436.jpg
#   inflating: posters/1885438.jpg
#   inflating: posters/1885447.jpg
#   inflating: posters/1885448.jpg
#   inflating: posters/1885457.jpg
#   inflating: posters/1885461.jpg
#   inflating: posters/1885462.jpg
#   inflating: posters/1885467.jpg
#   inflating: posters/1885469.jpg
#   inflating: posters/1885472.jpg
#   inflating: posters/1885474.jpg
#   inflating: posters/1885480.jpg
#   inflating: posters/1885481.jpg
#   inflating: posters/1885483.jpg
#   inflating: posters/1885484.jpg
#   inflating: posters/1885485.jpg
#   inflating: posters/1885493.jpg
#   inflating: posters/1885497.jpg
#   inflating: posters/1885500.jpg
#   inflating: posters/1885503.jpg
#   inflating: posters/1885515.jpg
#   inflating: posters/1885517.jpg
#   inflating: posters/1885518.jpg
#   inflating: posters/1885523.jpg
#   inflating: posters/1885531.jpg
#   inflating: posters/1885533.jpg
#   inflating: posters/1885536.jpg
#   inflating: posters/1885538.jpg
#   inflating: posters/1885540.jpg
#   inflating: posters/1885542.jpg
#   inflating: posters/1885544.jpg
#   inflating: posters/1885545.jpg
#   inflating: posters/1885546.jpg
#   inflating: posters/1885559.jpg
#   inflating: posters/1885565.jpg
#   inflating: posters/1885566.jpg
#   inflating: posters/1885575.jpg
#   inflating: posters/1885576.jpg
#   inflating: posters/1885582.jpg
#   inflating: posters/1885585.jpg
#   inflating: posters/1885596.jpg
#   inflating: posters/1885607.jpg
#   inflating: posters/1885611.jpg
#   inflating: posters/1885613.jpg
#   inflating: posters/1885615.jpg
#   inflating: posters/1885618.jpg
#   inflating: posters/1885619.jpg
#   inflating: posters/1885621.jpg
#   inflating: posters/1885623.jpg
#   inflating: posters/1885624.jpg
#   inflating: posters/1885630.jpg
#   inflating: posters/1885631.jpg
#   inflating: posters/1885633.jpg
#   inflating: posters/1885637.jpg
#   inflating: posters/1885641.jpg
#   inflating: posters/1885643.jpg
#   inflating: posters/1885644.jpg
#   inflating: posters/1885645.jpg
#   inflating: posters/1885647.jpg
#   inflating: posters/1885650.jpg
#   inflating: posters/1885652.jpg
#   inflating: posters/1885657.jpg
#   inflating: posters/1885659.jpg
#   inflating: posters/1885660.jpg
#   inflating: posters/1885669.jpg
#   inflating: posters/1885672.jpg
#   inflating: posters/1885673.jpg
#   inflating: posters/1885678.jpg
#   inflating: posters/1885690.jpg
#   inflating: posters/1885698.jpg
#   inflating: posters/1885700.jpg
#   inflating: posters/1885701.jpg
#   inflating: posters/1885702.jpg
#   inflating: posters/1885708.jpg
#   inflating: posters/1885710.jpg
#   inflating: posters/1885711.jpg
#   inflating: posters/1885712.jpg
#   inflating: posters/1885713.jpg
#   inflating: posters/1885714.jpg
#   inflating: posters/1885728.jpg
#   inflating: posters/1885729.jpg
#   inflating: posters/1885734.jpg
#   inflating: posters/1885735.jpg
#   inflating: posters/1885740.jpg
#   inflating: posters/1885743.jpg
#   inflating: posters/1885744.jpg
#   inflating: posters/1885745.jpg
#   inflating: posters/1885746.jpg
#   inflating: posters/1885749.jpg
#   inflating: posters/1885753.jpg
#   inflating: posters/1885754.jpg
#   inflating: posters/1885758.jpg
#   inflating: posters/1885760.jpg
#   inflating: posters/1885770.jpg
#   inflating: posters/1885772.jpg
#   inflating: posters/1885777.jpg
#   inflating: posters/1885783.jpg
#   inflating: posters/1885788.jpg
#   inflating: posters/1885789.jpg
#   inflating: posters/1885798.jpg
#   inflating: posters/1885812.jpg
#   inflating: posters/1885817.jpg
#   inflating: posters/1885821.jpg
#   inflating: posters/1885822.jpg
#   inflating: posters/1885830.jpg
#   inflating: posters/1885831.jpg
#   inflating: posters/1885835.jpg
#   inflating: posters/1885841.jpg
#   inflating: posters/1885843.jpg
#   inflating: posters/1885846.jpg
#   inflating: posters/1885848.jpg
#   inflating: posters/1885854.jpg
#   inflating: posters/1885865.jpg
#   inflating: posters/1885872.jpg
#   inflating: posters/1885875.jpg
#   inflating: posters/1885879.jpg
#   inflating: posters/1885880.jpg
#   inflating: posters/1885893.jpg
#   inflating: posters/1885894.jpg
#   inflating: posters/1885896.jpg
#   inflating: posters/1885897.jpg
#   inflating: posters/1885903.jpg
#   inflating: posters/1885909.jpg
#   inflating: posters/1885911.jpg
#   inflating: posters/1885912.jpg
#   inflating: posters/1885913.jpg
#   inflating: posters/1885914.jpg
#   inflating: posters/1885919.jpg
#   inflating: posters/1885928.jpg
#   inflating: posters/1885929.jpg
#   inflating: posters/1885930.jpg
#   inflating: posters/1885931.jpg
#   inflating: posters/1885933.jpg
#   inflating: posters/1885938.jpg
#   inflating: posters/1885942.jpg
#   inflating: posters/1885948.jpg
#   inflating: posters/1885949.jpg
#   inflating: posters/1885950.jpg
#   inflating: posters/1885953.jpg
#   inflating: posters/1885967.jpg
#   inflating: posters/1885969.jpg
#   inflating: posters/1885972.jpg
#   inflating: posters/1885977.jpg
#   inflating: posters/1885980.jpg
#   inflating: posters/1885982.jpg
#   inflating: posters/1885988.jpg
#   inflating: posters/1885989.jpg
#   inflating: posters/1885996.jpg
#   inflating: posters/1886002.jpg
#   inflating: posters/1886010.jpg
#   inflating: posters/1886011.jpg
#   inflating: posters/1886013.jpg
#   inflating: posters/1886015.jpg
#   inflating: posters/1886016.jpg
#   inflating: posters/1886017.jpg
#   inflating: posters/1886018.jpg
#   inflating: posters/1886019.jpg
#   inflating: posters/1886020.jpg
#   inflating: posters/1886021.jpg
#   inflating: posters/1886022.jpg
#   inflating: posters/1886023.jpg
#   inflating: posters/1886024.jpg
#   inflating: posters/1886025.jpg
#   inflating: posters/1886027.jpg
#   inflating: posters/1886030.jpg
#   inflating: posters/1886031.jpg
#   inflating: posters/1886034.jpg
#   inflating: posters/1886036.jpg
#   inflating: posters/1886037.jpg
#   inflating: posters/1886045.jpg
#   inflating: posters/1886046.jpg
#   inflating: posters/1886053.jpg
#   inflating: posters/1886063.jpg
#   inflating: posters/1886065.jpg
#   inflating: posters/1886071.jpg
#   inflating: posters/1886072.jpg
#   inflating: posters/1886076.jpg
#   inflating: posters/1886080.jpg
#   inflating: posters/1886083.jpg
#   inflating: posters/1886085.jpg
#   inflating: posters/1886086.jpg
#   inflating: posters/1886090.jpg
#   inflating: posters/1886091.jpg
#   inflating: posters/1886092.jpg
#   inflating: posters/1886096.jpg
#   inflating: posters/1886106.jpg
#   inflating: posters/1886108.jpg
#   inflating: posters/1886122.jpg
#   inflating: posters/1886140.jpg
#   inflating: posters/1886143.jpg
#   inflating: posters/1886150.jpg
#   inflating: posters/1886160.jpg
#   inflating: posters/1886161.jpg
#   inflating: posters/1886359.jpg
#   inflating: posters/1886360.jpg
#   inflating: posters/1886361.jpg
#   inflating: posters/1886362.jpg
#   inflating: posters/1886363.jpg
#   inflating: posters/1886364.jpg
#   inflating: posters/1886365.jpg
#   inflating: posters/1886367.jpg
#   inflating: posters/1886407.jpg
#   inflating: posters/1886415.jpg
#   inflating: posters/1886423.jpg
#   inflating: posters/1886424.jpg
#   inflating: posters/1886427.jpg
#   inflating: posters/1886428.jpg
#   inflating: posters/1886431.jpg
#   inflating: posters/1886433.jpg
#   inflating: posters/1886437.jpg
#   inflating: posters/1886440.jpg
#   inflating: posters/1886445.jpg
#   inflating: posters/1886448.jpg
#   inflating: posters/1886455.jpg
#   inflating: posters/1886457.jpg
#   inflating: posters/1886458.jpg
#   inflating: posters/1886459.jpg
#   inflating: posters/1886460.jpg
#   inflating: posters/1886461.jpg
#   inflating: posters/1886473.jpg
#   inflating: posters/1886481.jpg
#   inflating: posters/1886482.jpg
#   inflating: posters/1886484.jpg
#   inflating: posters/1886527.jpg
#   inflating: posters/1886528.jpg
#   inflating: posters/1886538.jpg
#   inflating: posters/1886544.jpg
#   inflating: posters/1886545.jpg
#   inflating: posters/1886547.jpg
#   inflating: posters/1886548.jpg
#   inflating: posters/1886550.jpg
#   inflating: posters/1886551.jpg
#   inflating: posters/1886552.jpg
#   inflating: posters/1886585.jpg
#   inflating: posters/1886594.jpg
#   inflating: posters/1886604.jpg
#   inflating: posters/1886605.jpg
#   inflating: posters/1886608.jpg
#   inflating: posters/1886609.jpg
#   inflating: posters/1886610.jpg
#   inflating: posters/1886615.jpg
#   inflating: posters/1886616.jpg
#   inflating: posters/1886632.jpg
#   inflating: posters/1886655.jpg
#   inflating: posters/1886656.jpg
#   inflating: posters/1886657.jpg
#   inflating: posters/1886658.jpg
#   inflating: posters/1886659.jpg
#   inflating: posters/1886661.jpg
#   inflating: posters/1886667.jpg
#   inflating: posters/1886671.jpg
#   inflating: posters/1886673.jpg
#   inflating: posters/1886676.jpg
#   inflating: posters/1886787.jpg
#   inflating: posters/1886793.jpg
#   inflating: posters/1886798.jpg
#   inflating: posters/1886802.jpg
#   inflating: posters/1886804.jpg
#   inflating: posters/1886808.jpg
#   inflating: posters/1886851.jpg
#   inflating: posters/1886853.jpg
#   inflating: posters/1886854.jpg
#   inflating: posters/1886855.jpg
#   inflating: posters/1886864.jpg
#   inflating: posters/1886865.jpg
#   inflating: posters/1886870.jpg
#   inflating: posters/1886873.jpg
#   inflating: posters/1886874.jpg
#   inflating: posters/1886876.jpg
#   inflating: posters/1886877.jpg
#   inflating: posters/1886879.jpg
#   inflating: posters/1886881.jpg
#   inflating: posters/1886883.jpg
#   inflating: posters/1886925.jpg
#   inflating: posters/1886927.jpg
#   inflating: posters/1886936.jpg
#   inflating: posters/1886937.jpg
#   inflating: posters/1886938.jpg
#   inflating: posters/1886939.jpg
#   inflating: posters/1886940.jpg
#   inflating: posters/1886958.jpg
#   inflating: posters/1886959.jpg
#   inflating: posters/1886977.jpg
#   inflating: posters/1886979.jpg
#   inflating: posters/1886980.jpg
#   inflating: posters/1886982.jpg
#   inflating: posters/1887027.jpg
#   inflating: posters/1887028.jpg
#   inflating: posters/1887033.jpg
#   inflating: posters/1887034.jpg
#   inflating: posters/1887039.jpg
#   inflating: posters/1887041.jpg
#   inflating: posters/1887047.jpg
#   inflating: posters/1887061.jpg
#   inflating: posters/1887063.jpg
#   inflating: posters/1887068.jpg
#   inflating: posters/1887074.jpg
#   inflating: posters/1887076.jpg
#   inflating: posters/1887083.jpg
#   inflating: posters/1887085.jpg
#   inflating: posters/1887109.jpg
#   inflating: posters/1887110.jpg
#   inflating: posters/1887111.jpg
#   inflating: posters/1887112.jpg
#   inflating: posters/1887113.jpg
#   inflating: posters/1887132.jpg
#   inflating: posters/1887136.jpg
#   inflating: posters/1887139.jpg
#   inflating: posters/1887141.jpg
#   inflating: posters/1887180.jpg
#   inflating: posters/1887181.jpg
#   inflating: posters/1887182.jpg
#   inflating: posters/1887186.jpg
#   inflating: posters/1887197.jpg
#   inflating: posters/1887198.jpg
#   inflating: posters/1887199.jpg
#   inflating: posters/1887206.jpg
#   inflating: posters/1887214.jpg
#   inflating: posters/1887221.jpg
#   inflating: posters/1887261.jpg
#   inflating: posters/1887368.jpg
#   inflating: posters/1887369.jpg
#   inflating: posters/1887372.jpg
#   inflating: posters/1887373.jpg
#   inflating: posters/1887374.jpg
#   inflating: posters/1887376.jpg
#   inflating: posters/1887379.jpg
#   inflating: posters/1887381.jpg
#   inflating: posters/1887383.jpg
#   inflating: posters/1887384.jpg
#   inflating: posters/1887387.jpg
#   inflating: posters/1887389.jpg
#   inflating: posters/1887391.jpg
#   inflating: posters/1887392.jpg
#   inflating: posters/1887393.jpg
#   inflating: posters/1887394.jpg
#   inflating: posters/1887395.jpg
#   inflating: posters/1887396.jpg
#   inflating: posters/1887397.jpg
#   inflating: posters/1887399.jpg
#   inflating: posters/1887400.jpg
#   inflating: posters/1887406.jpg
#   inflating: posters/1887407.jpg
#   inflating: posters/1887408.jpg
#   inflating: posters/1887409.jpg
#   inflating: posters/1887410.jpg
#   inflating: posters/1887411.jpg
#   inflating: posters/1887412.jpg
#   inflating: posters/1887429.jpg
#   inflating: posters/1887430.jpg
#   inflating: posters/1887432.jpg
#   inflating: posters/1887434.jpg
#   inflating: posters/1887447.jpg
#   inflating: posters/1887448.jpg
#   inflating: posters/1887450.jpg
#   inflating: posters/1887451.jpg
#   inflating: posters/1887459.jpg
#   inflating: posters/1887461.jpg
#   inflating: posters/1887462.jpg
#   inflating: posters/1887463.jpg
#   inflating: posters/1887464.jpg
#   inflating: posters/1887465.jpg
#   inflating: posters/1887466.jpg
#   inflating: posters/1887467.jpg
#   inflating: posters/1887468.jpg
#   inflating: posters/1887470.jpg
#   inflating: posters/1887471.jpg
#   inflating: posters/1887473.jpg
#   inflating: posters/1887474.jpg
#   inflating: posters/1887475.jpg
#   inflating: posters/1887476.jpg
#   inflating: posters/1887477.jpg
#   inflating: posters/1887478.jpg
#   inflating: posters/1887480.jpg
#   inflating: posters/1887481.jpg
#   inflating: posters/1887482.jpg
#   inflating: posters/1887483.jpg
#   inflating: posters/1887484.jpg
#   inflating: posters/1887485.jpg
#   inflating: posters/1887486.jpg
#   inflating: posters/1887487.jpg
#   inflating: posters/1887488.jpg
#   inflating: posters/1887489.jpg
#   inflating: posters/1887490.jpg
#   inflating: posters/1887491.jpg
#   inflating: posters/1887493.jpg
#   inflating: posters/1887496.jpg
#   inflating: posters/1887497.jpg
#   inflating: posters/1887498.jpg
#   inflating: posters/1887501.jpg
#   inflating: posters/1887503.jpg
#   inflating: posters/1887505.jpg
#   inflating: posters/1887510.jpg
#   inflating: posters/1887511.jpg
#   inflating: posters/1887512.jpg
#   inflating: posters/1887513.jpg
#   inflating: posters/1887516.jpg
#   inflating: posters/1887517.jpg
#   inflating: posters/1887518.jpg
#   inflating: posters/1887520.jpg
#   inflating: posters/1887522.jpg
#   inflating: posters/1887523.jpg
#   inflating: posters/1887525.jpg
#   inflating: posters/1887526.jpg
#   inflating: posters/1887527.jpg
#   inflating: posters/1887528.jpg
#   inflating: posters/1887529.jpg
#   inflating: posters/1887531.jpg
#   inflating: posters/1887532.jpg
#   inflating: posters/1887533.jpg
#   inflating: posters/1887534.jpg
#   inflating: posters/1887535.jpg
#   inflating: posters/1887536.jpg
#   inflating: posters/1887537.jpg
#   inflating: posters/1887538.jpg
#   inflating: posters/1887539.jpg
#   inflating: posters/1887540.jpg
#   inflating: posters/1887542.jpg
#   inflating: posters/1887543.jpg
#   inflating: posters/1887544.jpg
#   inflating: posters/1887550.jpg
#   inflating: posters/1887574.jpg
#   inflating: posters/1887576.jpg
#   inflating: posters/1887579.jpg
#   inflating: posters/1887580.jpg
#   inflating: posters/1887581.jpg
#   inflating: posters/1887582.jpg
#   inflating: posters/1887589.jpg
#   inflating: posters/1887590.jpg
#   inflating: posters/1887591.jpg
#   inflating: posters/1887592.jpg
#   inflating: posters/1887593.jpg
#   inflating: posters/1887594.jpg
#   inflating: posters/1887595.jpg
#   inflating: posters/1887596.jpg
#   inflating: posters/1887597.jpg
#   inflating: posters/1887599.jpg
#   inflating: posters/1887600.jpg
#   inflating: posters/1887601.jpg
#   inflating: posters/1887602.jpg
#   inflating: posters/1887603.jpg
#   inflating: posters/1887604.jpg
#   inflating: posters/1887605.jpg
#   inflating: posters/1887606.jpg
#   inflating: posters/1887607.jpg
#   inflating: posters/1887608.jpg
#   inflating: posters/1887609.jpg
#   inflating: posters/1887610.jpg
#   inflating: posters/1887612.jpg
#   inflating: posters/1887613.jpg
#   inflating: posters/1887614.jpg
#   inflating: posters/1887615.jpg
#   inflating: posters/1887616.jpg
#   inflating: posters/1887617.jpg
#   inflating: posters/1887618.jpg
#   inflating: posters/1887619.jpg
#   inflating: posters/1887620.jpg
#   inflating: posters/1887621.jpg
#   inflating: posters/1887622.jpg
#   inflating: posters/1887623.jpg
#   inflating: posters/1887624.jpg
#   inflating: posters/1887626.jpg
#   inflating: posters/1887627.jpg
#   inflating: posters/1887628.jpg
#   inflating: posters/1887629.jpg
#   inflating: posters/1887630.jpg
#   inflating: posters/1887631.jpg
#   inflating: posters/1887632.jpg
#   inflating: posters/1887633.jpg
#   inflating: posters/1887634.jpg
#   inflating: posters/1887635.jpg
#   inflating: posters/1887636.jpg
#   inflating: posters/1887637.jpg
#   inflating: posters/1887638.jpg
#   inflating: posters/1887639.jpg
#   inflating: posters/1887640.jpg
#   inflating: posters/1887641.jpg
#   inflating: posters/1887642.jpg
#   inflating: posters/1887643.jpg
#   inflating: posters/1887644.jpg
#   inflating: posters/1887645.jpg
#   inflating: posters/1887647.jpg
#   inflating: posters/1887648.jpg
#   inflating: posters/1887651.jpg
#   inflating: posters/1887652.jpg
#   inflating: posters/1887653.jpg
#   inflating: posters/1887654.jpg
#   inflating: posters/1887655.jpg
#   inflating: posters/1887656.jpg
#   inflating: posters/1887658.jpg
#   inflating: posters/1887659.jpg
#   inflating: posters/1887660.jpg
#   inflating: posters/1887663.jpg
#   inflating: posters/1887664.jpg
#   inflating: posters/1887666.jpg
#   inflating: posters/1887667.jpg
#   inflating: posters/1887668.jpg
#   inflating: posters/1887672.jpg
#   inflating: posters/1887674.jpg
#   inflating: posters/1887675.jpg
#   inflating: posters/1887676.jpg
#   inflating: posters/1887677.jpg
#   inflating: posters/1887679.jpg
#   inflating: posters/1887680.jpg
#   inflating: posters/1887683.jpg
#   inflating: posters/1887689.jpg
#   inflating: posters/1887693.jpg
#   inflating: posters/1887697.jpg
#   inflating: posters/1887716.jpg
#   inflating: posters/1887717.jpg
#   inflating: posters/1887718.jpg
#   inflating: posters/1887719.jpg
#   inflating: posters/1887720.jpg
#   inflating: posters/1887721.jpg
#   inflating: posters/1887722.jpg
#   inflating: posters/1887723.jpg
#   inflating: posters/1887724.jpg
#   inflating: posters/1887725.jpg
#   inflating: posters/1887726.jpg
#   inflating: posters/1887728.jpg
#   inflating: posters/1887729.jpg
#   inflating: posters/1887730.jpg
#   inflating: posters/1887731.jpg
#   inflating: posters/1887733.jpg
#   inflating: posters/1887734.jpg
#   inflating: posters/1887736.jpg
#   inflating: posters/1887737.jpg
#   inflating: posters/1887739.jpg
#   inflating: posters/1887740.jpg
#   inflating: posters/1887741.jpg
#   inflating: posters/1887742.jpg
#   inflating: posters/1887744.jpg
#   inflating: posters/1887746.jpg
#   inflating: posters/1887747.jpg
#   inflating: posters/1887748.jpg
#   inflating: posters/1887749.jpg
#   inflating: posters/1887750.jpg
#   inflating: posters/1887751.jpg
#   inflating: posters/1887752.jpg
#   inflating: posters/1887753.jpg
#   inflating: posters/1887755.jpg
#   inflating: posters/1887758.jpg
#   inflating: posters/1887760.jpg
#   inflating: posters/1887761.jpg
#   inflating: posters/1887762.jpg
#   inflating: posters/1887764.jpg
#   inflating: posters/1887765.jpg
#   inflating: posters/1887767.jpg
#   inflating: posters/1887768.jpg
#   inflating: posters/1887769.jpg
#   inflating: posters/1887770.jpg
#   inflating: posters/1887771.jpg
#   inflating: posters/1887772.jpg
#   inflating: posters/1887773.jpg
#   inflating: posters/1887774.jpg
#   inflating: posters/1887775.jpg
#   inflating: posters/1887776.jpg
#   inflating: posters/1887777.jpg
#   inflating: posters/1887778.jpg
#   inflating: posters/1887779.jpg
#   inflating: posters/1887780.jpg
#   inflating: posters/1887781.jpg
# ...
#   inflating: posters/1895190.jpg
#   inflating: posters/1895212.jpg
#   inflating: posters/1895224.jpg
#   inflating: posters/1895225.jpg
#   inflating: posters/1895226.jpg
#   inflating: posters/1895230.jpg
#   inflating: posters/1895231.jpg
#   inflating: posters/1895233.jpg
#   inflating: posters/1895243.jpg
#   inflating: posters/1895244.jpg
#   inflating: posters/1895245.jpg
#   inflating: posters/1895252.jpg
#   inflating: posters/1895254.jpg
#   inflating: posters/1895264.jpg
#   inflating: posters/1895266.jpg
#   inflating: posters/1895269.jpg
#   inflating: posters/1895270.jpg
#   inflating: posters/1895271.jpg
#   inflating: posters/1895273.jpg
#   inflating: posters/1895276.jpg
#   inflating: posters/1895277.jpg
#   inflating: posters/1895278.jpg
#   inflating: posters/1895281.jpg
#   inflating: posters/1895283.jpg
#   inflating: posters/1895289.jpg
#   inflating: posters/1895294.jpg
#   inflating: posters/1895296.jpg
#   inflating: posters/1895297.jpg
#   inflating: posters/1895301.jpg
#   inflating: posters/1895303.jpg
#   inflating: posters/1895304.jpg
#   inflating: posters/1895307.jpg
#   inflating: posters/1895308.jpg
#   inflating: posters/1895311.jpg
#   inflating: posters/1895312.jpg
#   inflating: posters/1895313.jpg
#   inflating: posters/1895314.jpg
#   inflating: posters/1895317.jpg
#   inflating: posters/1895318.jpg
#   inflating: posters/1895319.jpg
#   inflating: posters/1895320.jpg
#   inflating: posters/1895323.jpg
#   inflating: posters/1895325.jpg
#   inflating: posters/1895327.jpg
#   inflating: posters/1895331.jpg
#   inflating: posters/1895339.jpg
#   inflating: posters/1895353.jpg
#   inflating: posters/1895357.jpg
#   inflating: posters/1895358.jpg
#   inflating: posters/1895363.jpg
#   inflating: posters/1895365.jpg
#   inflating: posters/1895366.jpg
#   inflating: posters/1895367.jpg
#   inflating: posters/1895369.jpg
#   inflating: posters/1895370.jpg
#   inflating: posters/1895372.jpg
#   inflating: posters/1895373.jpg
#   inflating: posters/1895376.jpg
#   inflating: posters/1895377.jpg
#   inflating: posters/1895381.jpg
#   inflating: posters/1895382.jpg
#   inflating: posters/1895384.jpg
#   inflating: posters/1895392.jpg
#   inflating: posters/1895393.jpg
#   inflating: posters/1895403.jpg
#   inflating: posters/1895407.jpg
#   inflating: posters/1895408.jpg
#   inflating: posters/1895410.jpg
#   inflating: posters/1895414.jpg
#   inflating: posters/1895417.jpg
#   inflating: posters/1895418.jpg
#   inflating: posters/1895421.jpg
#   inflating: posters/1895425.jpg
#   inflating: posters/1895426.jpg
#   inflating: posters/1895431.jpg
#   inflating: posters/1895436.jpg
#   inflating: posters/1895437.jpg
#   inflating: posters/1895438.jpg
#   inflating: posters/1895439.jpg
#   inflating: posters/1895441.jpg
#   inflating: posters/1895442.jpg
#   inflating: posters/1895445.jpg
#   inflating: posters/1895447.jpg
#   inflating: posters/1895448.jpg
#   inflating: posters/1895449.jpg
#   inflating: posters/1895454.jpg
#   inflating: posters/1895457.jpg
#   inflating: posters/1895461.jpg
#   inflating: posters/1895467.jpg
#   inflating: posters/1895473.jpg
#   inflating: posters/1895474.jpg
#   inflating: posters/1895475.jpg
#   inflating: posters/1895480.jpg
#   inflating: posters/1895497.jpg
#   inflating: posters/1895498.jpg
#   inflating: posters/1895500.jpg
#   inflating: posters/1895507.jpg
#   inflating: posters/1895508.jpg
#   inflating: posters/1895509.jpg
#   inflating: posters/1895510.jpg
#   inflating: posters/1895511.jpg
#   inflating: posters/1895512.jpg
#   inflating: posters/1895513.jpg
#   inflating: posters/1895520.jpg
#   inflating: posters/1895526.jpg
#   inflating: posters/1895529.jpg
#   inflating: posters/1895531.jpg
#   inflating: posters/1895532.jpg
#   inflating: posters/1895536.jpg
#   inflating: posters/1895537.jpg
#   inflating: posters/1895538.jpg
#   inflating: posters/1895540.jpg
#   inflating: posters/1895541.jpg
#   inflating: posters/1895542.jpg
#   inflating: posters/1895543.jpg
#   inflating: posters/1895544.jpg
#   inflating: posters/1895545.jpg
#   inflating: posters/1895546.jpg
#   inflating: posters/1895547.jpg
#   inflating: posters/1895548.jpg
#   inflating: posters/1895555.jpg
#   inflating: posters/1895559.jpg
#   inflating: posters/1895562.jpg
#   inflating: posters/1895566.jpg
#   inflating: posters/1895567.jpg
#   inflating: posters/1895568.jpg
#   inflating: posters/1895570.jpg
#   inflating: posters/1895572.jpg
#   inflating: posters/1895575.jpg
#   inflating: posters/1895590.jpg
#   inflating: posters/1895596.jpg
#   inflating: posters/1895597.jpg
#   inflating: posters/1895598.jpg
#   inflating: posters/1895599.jpg
#   inflating: posters/1895600.jpg
#   inflating: posters/1895601.jpg
#   inflating: posters/1895604.jpg
#   inflating: posters/1895605.jpg
#   inflating: posters/1895607.jpg
#   inflating: posters/1895611.jpg
#   inflating: posters/1895614.jpg
#   inflating: posters/1895615.jpg
#   inflating: posters/1895616.jpg
#   inflating: posters/1895617.jpg
#   inflating: posters/1895620.jpg
#   inflating: posters/1895626.jpg
#   inflating: posters/1895631.jpg
#   inflating: posters/1895632.jpg
#   inflating: posters/1895633.jpg
#   inflating: posters/1895634.jpg
#   inflating: posters/1895635.jpg
#   inflating: posters/1895637.jpg
#   inflating: posters/1895641.jpg
#   inflating: posters/1895643.jpg
#   inflating: posters/1895646.jpg
#   inflating: posters/1895647.jpg
#   inflating: posters/1895651.jpg
#   inflating: posters/1895653.jpg
#   inflating: posters/1895656.jpg
#   inflating: posters/1895657.jpg
#   inflating: posters/1895659.jpg
#   inflating: posters/1895661.jpg
#   inflating: posters/1895663.jpg
#   inflating: posters/1895664.jpg
#   inflating: posters/1895667.jpg
#   inflating: posters/1895668.jpg
#   inflating: posters/1895672.jpg
#   inflating: posters/1895678.jpg
#   inflating: posters/1895679.jpg
#   inflating: posters/1895681.jpg
#   inflating: posters/1895682.jpg
#   inflating: posters/1895685.jpg
#   inflating: posters/1895692.jpg
#   inflating: posters/1895699.jpg
#   inflating: posters/1895700.jpg
#   inflating: posters/1895701.jpg
#   inflating: posters/1895706.jpg
#   inflating: posters/1895707.jpg
#   inflating: posters/1895710.jpg
#   inflating: posters/1895712.jpg
#   inflating: posters/1895715.jpg
#   inflating: posters/1895718.jpg
#   inflating: posters/1895721.jpg
#   inflating: posters/1895728.jpg
#   inflating: posters/1895736.jpg
#   inflating: posters/1895739.jpg
#   inflating: posters/1895740.jpg
#   inflating: posters/1895748.jpg
#   inflating: posters/1895753.jpg
#   inflating: posters/1895763.jpg
#   inflating: posters/1895768.jpg
#   inflating: posters/1895770.jpg
#   inflating: posters/1895771.jpg
#   inflating: posters/1895775.jpg
#   inflating: posters/1895780.jpg
#   inflating: posters/1895781.jpg
#   inflating: posters/1895783.jpg
#   inflating: posters/1895786.jpg
#   inflating: posters/1895787.jpg
#   inflating: posters/1895788.jpg
#   inflating: posters/1895789.jpg
#   inflating: posters/1895791.jpg
#   inflating: posters/1895792.jpg
#   inflating: posters/1895793.jpg
#   inflating: posters/1895794.jpg
#   inflating: posters/1895795.jpg
#   inflating: posters/1895796.jpg
#   inflating: posters/1895800.jpg
#   inflating: posters/1895801.jpg
#   inflating: posters/1895804.jpg
#   inflating: posters/1895806.jpg
#   inflating: posters/1895807.jpg
#   inflating: posters/1895808.jpg
#   inflating: posters/1895809.jpg
#   inflating: posters/1895812.jpg
#   inflating: posters/1895818.jpg
#   inflating: posters/1895823.jpg
#   inflating: posters/1895824.jpg
#   inflating: posters/1895827.jpg
#   inflating: posters/1895828.jpg
#   inflating: posters/1895829.jpg
#   inflating: posters/1895830.jpg
#   inflating: posters/1895831.jpg
#   inflating: posters/1895838.jpg
#   inflating: posters/1895839.jpg
#   inflating: posters/1895842.jpg
#   inflating: posters/1895846.jpg
#   inflating: posters/1895849.jpg
#   inflating: posters/1895854.jpg
#   inflating: posters/1895855.jpg
#   inflating: posters/1895857.jpg
#   inflating: posters/1895858.jpg
#   inflating: posters/1895868.jpg
#   inflating: posters/1895869.jpg
#   inflating: posters/1895873.jpg
#   inflating: posters/1895874.jpg
#   inflating: posters/1895891.jpg
#   inflating: posters/1895892.jpg
#   inflating: posters/1895893.jpg
#   inflating: posters/1895896.jpg
#   inflating: posters/1895897.jpg
#   inflating: posters/1895898.jpg
#   inflating: posters/1895903.jpg
#   inflating: posters/1895904.jpg
#   inflating: posters/1895905.jpg
#   inflating: posters/1895906.jpg
#   inflating: posters/1895910.jpg
#   inflating: posters/1895917.jpg
#   inflating: posters/1895918.jpg
#   inflating: posters/1895919.jpg
#   inflating: posters/1895926.jpg
#   inflating: posters/1895928.jpg
#   inflating: posters/1895930.jpg
#   inflating: posters/1895931.jpg
#   inflating: posters/1895933.jpg
#   inflating: posters/1895937.jpg
#   inflating: posters/1895941.jpg
#   inflating: posters/1895942.jpg
#   inflating: posters/1895944.jpg
#   inflating: posters/1895946.jpg
#   inflating: posters/1895947.jpg
#   inflating: posters/1895955.jpg
#   inflating: posters/1895956.jpg
#   inflating: posters/1895957.jpg
#   inflating: posters/1895960.jpg
#   inflating: posters/1895962.jpg
#   inflating: posters/1895963.jpg
#   inflating: posters/1895967.jpg
#   inflating: posters/1895968.jpg
#   inflating: posters/1895969.jpg
#   inflating: posters/1895970.jpg
#   inflating: posters/1895971.jpg
#   inflating: posters/1895972.jpg
#   inflating: posters/1895976.jpg
#   inflating: posters/1895978.jpg
#   inflating: posters/1895979.jpg
#   inflating: posters/1895980.jpg
#   inflating: posters/1895981.jpg
#   inflating: posters/1895986.jpg
#   inflating: posters/1895989.jpg
#   inflating: posters/1895993.jpg
#   inflating: posters/1895995.jpg
#   inflating: posters/1895999.jpg
#   inflating: posters/1896001.jpg
#   inflating: posters/1896003.jpg
#   inflating: posters/1896005.jpg
#   inflating: posters/1896008.jpg
#   inflating: posters/1896009.jpg
#   inflating: posters/1896010.jpg
#   inflating: posters/1896015.jpg
#   inflating: posters/1896016.jpg
#   inflating: posters/1896022.jpg
#   inflating: posters/1896024.jpg
#   inflating: posters/1896025.jpg
#   inflating: posters/1896031.jpg
#   inflating: posters/1896032.jpg
#   inflating: posters/1896034.jpg
#   inflating: posters/1896041.jpg
#   inflating: posters/1896043.jpg
#   inflating: posters/1896044.jpg
#   inflating: posters/1896054.jpg
#   inflating: posters/1896060.jpg
#   inflating: posters/1896061.jpg
#   inflating: posters/1896063.jpg
#   inflating: posters/1896066.jpg
#   inflating: posters/1896070.jpg
#   inflating: posters/1896072.jpg
#   inflating: posters/1896075.jpg
#   inflating: posters/1896077.jpg
#   inflating: posters/1896081.jpg
#   inflating: posters/1896085.jpg
#   inflating: posters/1896096.jpg
#   inflating: posters/1896097.jpg
#   inflating: posters/1896098.jpg
#   inflating: posters/1896102.jpg
#   inflating: posters/1896103.jpg
#   inflating: posters/1896106.jpg
#   inflating: posters/1896110.jpg
#   inflating: posters/1896113.jpg
#   inflating: posters/1896114.jpg
#   inflating: posters/1896115.jpg
#   inflating: posters/1896118.jpg
#   inflating: posters/1896122.jpg
#   inflating: posters/1896123.jpg
#   inflating: posters/1896124.jpg
#   inflating: posters/1896125.jpg
#   inflating: posters/1896126.jpg
#   inflating: posters/1896127.jpg
#   inflating: posters/1896128.jpg
#   inflating: posters/1896129.jpg
#   inflating: posters/1896133.jpg
#   inflating: posters/1896134.jpg
#   inflating: posters/1896135.jpg
#   inflating: posters/1896136.jpg
#   inflating: posters/1896137.jpg
#   inflating: posters/1896138.jpg
#   inflating: posters/1896139.jpg
#   inflating: posters/1896140.jpg
#   inflating: posters/1896142.jpg
#   inflating: posters/1896145.jpg
#   inflating: posters/1896157.jpg
#   inflating: posters/1896163.jpg
#   inflating: posters/1896165.jpg
#   inflating: posters/1896166.jpg
#   inflating: posters/1896168.jpg
#   inflating: posters/1896172.jpg
#   inflating: posters/1896176.jpg
#   inflating: posters/1896178.jpg
#   inflating: posters/1896181.jpg
#   inflating: posters/1896196.jpg
#   inflating: posters/1896197.jpg
#   inflating: posters/1896199.jpg
#   inflating: posters/1896206.jpg
#   inflating: posters/1896207.jpg
#   inflating: posters/1896208.jpg
#   inflating: posters/1896210.jpg
#   inflating: posters/1896215.jpg
#   inflating: posters/1896216.jpg
#   inflating: posters/1896229.jpg
#   inflating: posters/1896231.jpg
#   inflating: posters/1896232.jpg
#   inflating: posters/1896236.jpg
#   inflating: posters/1896240.jpg
#   inflating: posters/1896241.jpg
#   inflating: posters/1896242.jpg
#   inflating: posters/1896243.jpg
#   inflating: posters/1896244.jpg
#   inflating: posters/1896248.jpg
#   inflating: posters/1896249.jpg
#   inflating: posters/1896254.jpg
#   inflating: posters/1896259.jpg
#   inflating: posters/1896260.jpg
#   inflating: posters/1896265.jpg
#   inflating: posters/1896270.jpg
#   inflating: posters/1896272.jpg
#   inflating: posters/1896278.jpg
#   inflating: posters/1896282.jpg
#   inflating: posters/1896287.jpg
#   inflating: posters/1896288.jpg
#   inflating: posters/1896293.jpg
#   inflating: posters/1896301.jpg
#   inflating: posters/1896302.jpg
#   inflating: posters/1896303.jpg
#   inflating: posters/1896304.jpg
#   inflating: posters/1896307.jpg
#   inflating: posters/1896309.jpg
#   inflating: posters/1896310.jpg
#   inflating: posters/1896311.jpg
#   inflating: posters/1896316.jpg
#   inflating: posters/1896318.jpg
#   inflating: posters/1896322.jpg
#   inflating: posters/1896326.jpg
#   inflating: posters/1896327.jpg
#   inflating: posters/1896328.jpg
#   inflating: posters/1896329.jpg
#   inflating: posters/1896330.jpg
#   inflating: posters/1896331.jpg
#   inflating: posters/1896332.jpg
#   inflating: posters/1896333.jpg
#   inflating: posters/1896334.jpg
#   inflating: posters/1896335.jpg
#   inflating: posters/1896336.jpg
#   inflating: posters/1896337.jpg
#   inflating: posters/1896351.jpg
#   inflating: posters/1896352.jpg
#   inflating: posters/1896355.jpg
#   inflating: posters/1896361.jpg
#   inflating: posters/1896363.jpg
#   inflating: posters/1896364.jpg
#   inflating: posters/1896367.jpg
#   inflating: posters/1896371.jpg
#   inflating: posters/1896372.jpg
#   inflating: posters/1896373.jpg
#   inflating: posters/1896374.jpg
#   inflating: posters/1896382.jpg
#   inflating: posters/1896388.jpg
#   inflating: posters/1896391.jpg
#   inflating: posters/1896392.jpg
#   inflating: releases.csv
#   inflating: studios.csv
#   inflating: themes.csv

# %% [markdown]
# # I- Pre-processing the data

# %% [markdown]
# We start by loading in a panda dataframe our genres.csv file.

# %%
df_genre = pd.read_csv("genres.csv")

print(df_genre.shape)
print("Genres :\n", np.sort(df_genre['genre'].unique()), "\n")
print("Numbers of genre :", df_genre['genre'].nunique(), "\n")
print("Numbers of film :", df_genre['id'].nunique(), "\n")
print("Occurences of each genre in the dataset : \n\n", df_genre['genre'].value_counts(), "\n")
print("first lines of the dataset : \n", df_genre.head(10))
# Out:
# (990770, 2)
# Genres :
#  ['Action' 'Adventure' 'Animation' 'Comedy' 'Crime' 'Documentary' 'Drama'
#  'Family' 'Fantasy' 'History' 'Horror' 'Music' 'Mystery' 'Romance'
#  'Science Fiction' 'TV Movie' 'Thriller' 'War' 'Western']
#
# Numbers of genre : 19
#
# Numbers of film : 638632
#
# Occurences of each genre in the dataset :
#
#  genre
# Drama              219936
# Documentary        153666
# Comedy             134220
# Animation           54701
# Romance             49605
# Horror              48688
# Thriller            44201
# Music               41871
# Action              40291
# Crime               33975
# Family              26612
# TV Movie            24596
# Adventure           22281
# Fantasy             21013
# Mystery             20046
# Science Fiction     19901
# History             16217
# War                 10312
# Western              8638
# Name: count, dtype: int64
#
# first lines of the dataset :
#          id            genre
# 0  1000001           Comedy
# 1  1000001          Fantasy
# 2  1000001        Adventure
# 3  1000002           Comedy
# 4  1000002         Thriller
# 5  1000002            Drama
# 6  1000003  Science Fiction
# 7  1000003           Action
# 8  1000003        Adventure
# 9  1000004            Drama

# %% [markdown]
# Then we start cleaning and creating the different dataset we will need for the following part of this notebook.
# So here are grouped together all the functions for preprocessing our dataset, and creating the different datasets that we'll use later.

# %%
# function that deletes films that are not associated with a poster
def delete_films_without_poster(df, path_posters):

    existing_poster = os.listdir(path_posters)
    mask_existing_poster = df['filename'].isin(existing_poster)
    df_fwp = df[mask_existing_poster].copy()

    return df_fwp


# function that deletes films associated with no genre
def delete_films_without_genre(df):

    # delete Na value
    df_fwg = df.dropna(subset=['genre'])
    # delete blank value
    df_fwg = df_fwg[df_fwg['genre'].str.strip() != '']

    return df_fwg


# function that deletes films associated with more than N genres
def delete_films_w_more_N_genre(df):

    N = 3
    genre_counts = df['id'].value_counts()
    valid_films = genre_counts[genre_counts <= N].index
    df_valid = df[df['id'].isin(valid_films)].reset_index()
    df_valid = df_valid.drop(columns=['index'])

    return df_valid

# function that delete all the film associated to a genre, and therefore the genre itself
def delete_genre(df, genre):

    df_del = df[df['genre'] != genre].reset_index(drop=True)
    df_del = df_del.sample(frac=1).reset_index(drop=True)

    return df_del

# function that balanced a datset such that no genre are represented over the limits n
def balance_genres(df, n):

    df_eq = df.groupby('genre').apply(lambda x: x.sample(min(len(x), n))).reset_index(drop=True)

    return df_eq

# function that select the 6 most represented genre
def process_select_genre(df):

    top_genre = df['genre'].value_counts().nlargest(6).index.tolist()
    df_select = df.copy()

    for genre in df['genre'].unique():
        if genre not in top_genre:
            df_select = delete_genre(df_select, genre)

    return df_select


# function that returns films associated to one and only one genre
def films_with_one_genre(df):

    genre_counts = df['id'].value_counts()
    films_with_only_one_genre = genre_counts[genre_counts == 1].index
    df_one = df[df['id'].isin(films_with_only_one_genre)].reset_index()
    df_one = df_one.drop(columns=['index'])
    df_one = df_one.sample(frac=1).reset_index(drop=True) ##

    return df_one


# function that creates a dictionnary where each genre is associated to an integer. We'll use it later for one hot encoding.
def create_dict_genre_to_index(df_dict, name):

    list_of_genre = np.sort(df_dict['genre'].unique())
    genre_to_index = {genre: index for index, genre in enumerate(list_of_genre)}
    with open(f'{name}.json', 'w') as json_file:
        json.dump(genre_to_index, json_file)

    return 0


# function that groups the genre associated to each film in a list
def group_the_genre(df):

    df_grp = df.groupby('filename')['genre'].apply(list).reset_index()
    df_grp = df_grp.sample(frac=1).reset_index(drop=True)

    return df_grp


# function that splits the dataframe s.t : train set = 60% - val set = 20% - test set = 20%
def split_dataframe(df):

    df_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
    df_train, df_val = train_test_split(df_train, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

    return df_train, df_val, df_test

def calculate_sample_weights(df):

    genre_counts = df['genre'].value_counts()

    inverse_counts = 1.0 / genre_counts

    normalized_weights = inverse_counts / inverse_counts.sum()

    sorted_genres = sorted(normalized_weights.index)

    sorted_weights = np.array([normalized_weights[genre] for genre in sorted_genres])

    return sorted_weights


def process_df(df, poster_path):

    #we create a dictionnary, each genre associate to an index from 0 to 18, for latter use.
    create_dict_genre_to_index(df, 'genre_to_index')

    # we add a column filename
    df['filename'] = df['id'].astype(str) + '.jpg'

    # we delete films without poster
    df = delete_films_without_poster(df, poster_path)

    # we delete films without genre (if there are)
    df = delete_films_without_genre(df)

    # we delete films with more than N (here N=3) genre
    df = delete_films_w_more_N_genre(df)
    weight_full = calculate_sample_weights(df)
    # we shuffle the dataset, because the films are not well spread.
    #df = df.sample(frac=1).reset_index(drop=True)

    df_one = films_with_one_genre(df)
    weight_one_genre = calculate_sample_weights(df_one)

    df_genre_selected = process_select_genre(df_one)
    create_dict_genre_to_index(df_genre_selected, 'genre_to_index_selected')
    df_genre_selected = balance_genres(df_genre_selected, 25000)
    weight_selected = calculate_sample_weights(df_genre_selected)

    df_one = group_the_genre(df_one)
    df_genre_selected = group_the_genre(df_genre_selected)
    df_full_grp = group_the_genre(df)

    df_one_train, df_one_val, df_one_test = split_dataframe(df_one)
    df_full_train, df_full_val, df_full_test = split_dataframe(df_full_grp)
    df_selected_train, df_selected_val, df_selected_test = split_dataframe(df_genre_selected)


    # we save these dataset, in order to do not need to repeat this part again
    df.to_csv('dataframe/clean_dataframe.csv', index=False)

    df_one.to_csv('dataframe/df_one_genre.csv', index=False)
    df_one_train.to_csv('dataframe/training_set_one_genre.csv', index=False)
    df_one_val.to_csv('dataframe/validation_set_one_genre.csv', index=False)
    df_one_test.to_csv('dataframe/test_set_one_genre.csv', index=False)

    df_full_grp.to_csv('dataframe/df_full_grouped.csv', index=False)
    df_full_train.to_csv('dataframe/training_set_full.csv', index=False)
    df_full_val.to_csv('dataframe/validation_set_full.csv', index=False)
    df_full_test.to_csv('dataframe/test_set_full.csv', index=False)

    df_genre_selected.to_csv('dataframe/df_genres_selected.csv', index=False)
    df_selected_train.to_csv('dataframe/training_set_genres_selected.csv', index=False)
    df_selected_val.to_csv('dataframe/validation_set_genres_selected.csv', index=False)
    df_selected_test.to_csv('dataframe/test_set_genres_selected.csv', index=False)

    np.save('weight_full.npy', weight_full)
    np.save('weight_one_genre.npy', weight_one_genre)
    np.save('weight_selected.npy', weight_selected)

    return df

# %%
POSTER_PATH = 'posters/'
df = process_df(df_genre, POSTER_PATH)

# %% [markdown]
# Now that the first stage of pre-processing has been completed, we can get down to business and try to build a model that allows us to guess the genre of a film from its poster.
# This notebook is organised according to the order of reasoning that has been carried out, and so we naively start by trying to guess the genres of the films on the entire dataset. In other words, we keep the 19 genres, and each film can be associated with several genres. This kind of problem refers to a multi-label classification problem.

# %% [markdown]
# # II- Multi-labels Classification (MLC)

# %% [markdown]
# So in this first part, We're going to consider the entire clean dataset, so we'll keep all 19 genres, as well as the films associated with several genres at once. Let's see some statistics about this dataset.

# %%
df_full = pd.read_csv("dataframe/clean_dataframe.csv")
df_full_grp = pd.read_csv("dataframe/df_full_grouped.csv")
print("Numbers of film in df_one_genre :", df_full_grp.shape[0],'\n')
print("Occurences of each genre in df_one_genre : \n\n", df_full['genre'].value_counts(), "\n")
print("How the first line of our dataset looks : \n", df_full_grp.head(10),'\n')
# Out:
# Numbers of film in df_one_genre : 539810
#
# Occurences of each genre in df_one_genre :
#
#  genre
# Drama              188213
# Documentary        124829
# Comedy             113841
# Romance             42917
# Animation           42070
# Horror              41941
# Music               36826
# Thriller            35692
# Action              31465
# Crime               27224
# Family              20562
# TV Movie            18440
# Adventure           15717
# Mystery             15038
# Science Fiction     14884
# Fantasy             14785
# History             13166
# War                  8365
# Western              7188
# Name: count, dtype: int64
#
# How the first line of our dataset looks :
#        filename                         genre
# 0  1817776.jpg  ['Adventure', 'Documentary']
# 1  1056047.jpg               ['Documentary']
# 2  1613442.jpg                     ['Music']
# 3  1623296.jpg                   ['Western']
# 4  1074576.jpg          ['Drama', 'Romance']
# 5  1521295.jpg                     ['Drama']
# 6  1347318.jpg               ['Documentary']
# 7  1003119.jpg                     ['Drama']
# 8  1246947.jpg               ['Documentary']
# 9  1704903.jpg           ['Action', 'Drama']

# %% [markdown]
# ### a) Loading and building training and validation set

# %%
SAMPLE_SIZE_1 = 5000
BATCH_SIZE_1 = 64
poster_dir = 'posters/'
AUTO = tf.data.experimental.AUTOTUNE
genre_Number = 19
global genre_Number

# %%
df_train = pd.read_csv("dataframe/training_set_full.csv")
df_train = df_train.sample(int(SAMPLE_SIZE_1*0.8), random_state=42)
df_val = pd.read_csv("dataframe/validation_set_full.csv")
df_val = df_val.sample(int(SAMPLE_SIZE_1*0.2), random_state=42)

# %%
print("Number of film in training set :", df_train.shape[0], "\n")
print("Number of film in validation set :", df_val.shape[0], "\n")
print("sum : ", df_train.shape[0]+df_val.shape[0], "\n")
# Out:
# Number of film in training set : 4000
#
# Number of film in validation set : 1000
#
# sum :  5000

# %%
def one_hot_encode(genre):

    global genre_Number
    if (genre_Number == 19):
        with open('genre_to_index.json', 'r') as json_file:
            GTI = json.load(json_file)
    else:
         with open('genre_to_index_selected.json', 'r') as json_file:
            GTI = json.load(json_file)

    genre_str = genre.numpy().decode('utf-8')
    genre_list = ast.literal_eval(genre_str)
    l = []

    for i in range(len(genre_list)):
        g = genre_list[i]
        int_lab = GTI.get(g, None)
        if int_lab is None:
            raise ValueError(f"Genre {g} non trouvé dans GTI.")
        l.append(int_lab)

    label = tf.one_hot(l, genre_Number)
    label = tf.reduce_sum(label, axis=0)

    return label


def transform_into_tf(df):

    filenames = df['filename'].tolist()
    genres = df['genre'].tolist()
    ds_dict = tf.data.Dataset.from_tensor_slices((tf.ragged.constant(genres), filenames))

    return ds_dict


def read_image(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [256, 256])
    image = tf.cast(image, tf.float32) / 255.0
    image.set_shape([256, 256, 3])
    return image


def parse_function(e0, e1):
    global genre_Number
    image_path = tf.strings.join([poster_dir, e1], separator=os.sep)
    image = read_image(image_path)
    label = tf.py_function(one_hot_encode, [e0], tf.float32)
    label.set_shape([genre_Number])
    return image, label

def get_dataset(image_file, df, batch_size):

    ds = transform_into_tf(df)
    dataset = ds.map(parse_function, num_parallel_calls=AUTO)
    #dataset = dataset.repeat()

    # Depend on the size of the dataset we are working with. If it can be entirely cached in RAM or not.
    # So if we only work on small sample we can use it.
    #dataset = dataset.cache()

    #dataset = dataset.shuffle(buffer_size=10000, reshuffle_each_iteration=True)
    dataset = dataset.batch(batch_size, drop_remainder=True, num_parallel_calls=AUTO)

    # fetch next batches while training on the current one
    dataset = dataset.prefetch(AUTO)

    return dataset

# %%
ds_train = get_dataset(poster_dir, df_train, BATCH_SIZE_1)
ds_val = get_dataset(poster_dir, df_val, BATCH_SIZE_1)

# %% [markdown]
# ### b) Creating and training the MLC model

# %% [markdown]
# We create the MLCModel class to define our model

# %%
class MLCModel:

    def __init__(self, input_shape=(256, 256, 3), num_classes=19, dropout_rate=0.3, seed=40):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.dropout_rate = dropout_rate
        self.seed = seed
        self.model = self.build_model()

    def build_model(self):
        model = Sequential()

        model.add(Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), input_shape=self.input_shape))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(2, 2))

        model.add(Conv2D(32, (3, 3)))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(2, 2))

        model.add(Conv2D(64, (3, 3)))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(2, 2))

        model.add(Flatten())
        model.add(Dropout(rate=self.dropout_rate, seed=self.seed))

        model.add(Dense(64))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(rate=self.dropout_rate, seed=self.seed))

        model.add(Dense(32))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(rate=self.dropout_rate, seed=self.seed))

        model.add(Dense(self.num_classes, activation='sigmoid'))

        return model

    def get_model(self):
        return self.model

# %%
mlc = MLCModel()
model_1 = mlc.get_model()
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# model compilation and architecture display #
model_1.compile(optimizer='adam', loss='binary_crossentropy')
model_1.summary()

# train the model #
hist_1 = model_1.fit(ds_train, epochs=2, validation_data=ds_val, callbacks = [early_stopping])
#model_1.save('model/mlc_model_adam_ss=10000_epoch=10.keras')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  batch_normalization (Batch  (None, 254, 254, 16)      64
#  Normalization)
#
#  activation (Activation)     (None, 254, 254, 16)      0
#
#  max_pooling2d (MaxPooling2  (None, 127, 127, 16)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  batch_normalization_1 (Bat  (None, 125, 125, 32)      128
#  chNormalization)
#
#  activation_1 (Activation)   (None, 125, 125, 32)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 60, 60, 64)        256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 60, 60, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 57600)             0
#
#  dropout (Dropout)           (None, 57600)             0
#
#  dense (Dense)               (None, 64)                3686464
#
#  batch_normalization_3 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 19)                627
#
# =================================================================
# Total params: 3713587 (14.17 MB)
# Trainable params: 3713171 (14.16 MB)
# Non-trainable params: 416 (1.62 KB)
# _________________________________________________________________
# Epoch 1/2
# 62/62 [==============================] - 621s 10s/step - loss: 0.6102 - val_loss: 0.4743
# Epoch 2/2
# 62/62 [==============================] - 657s 11s/step - loss: 0.4036 - val_loss: 0.3273

# %%
def plot_train_and_val_loss(hist):
    plt.plot(hist.history['loss'], color = 'blue', label = 'train_loss')
    plt.plot(hist.history['val_loss'], color = 'orange', label = 'validation_loss')
    plt.title('Loss on train and validation set through epoch')
    plt.legend()
    plt.show()
    return

# %%
plot_train_and_val_loss(hist_1)

# %% [markdown]
# ### c) Evaluation of the MLC model on test set

# %%
#from tensorflow.keras.models import load_model
#model_1 = load_model('model/mlc_model_adam_ss=10000_epoch=10.keras')

# %%
df_test = pd.read_csv("dataframe/test_set_full.csv")
df_test = df_test.sample(int(SAMPLE_SIZE_1*0.8), random_state=42)

# %%
ds_test = get_dataset(poster_dir, df_test, BATCH_SIZE_1)

# %%
model_1.evaluate(ds_test)
# Out:
# 62/62 [==============================] - 201s 3s/step - loss: 0.3252
# 0.3251788020133972

# %%
proba = model_1.predict(ds_test)
print(proba)
# Out:
# 42/62 [===================>..........] - ETA: 1:07

# %%
y_true = np.concatenate([y for x, y in ds_test], axis=0)

# %%
correct_predictions = 0
for i in range(len(proba)):
    best_indices = np.argsort(proba[i])[-3:]

    if any(y_true[i][index] == 1 for index in best_indices):
        correct_predictions += 1

average_at_least_one_good_pred = correct_predictions / len(proba)

# %%
print(average_at_least_one_good_pred)
# Out:
# 0.6590221774193549

# %% [markdown]
# # III- Multi-Class Classification (MCC)

# %% [markdown]
# In this second part we're trying to simplify the problem a little in the hope of achieving better results. For this purpose, we now consider the df_one_genre dataset, made up solely of films associated with a single genre.
# Here are some statistics about this dataset.

# %%
df_one_genre = pd.read_csv("dataframe/df_one_genre.csv")
print("Numbers of film in df_one_genre :", df_one_genre.shape[0],'\n')
print("Occurences of each genre in df_one_genre : \n\n", df_one_genre['genre'].value_counts(), "\n")
# Out:
# Numbers of film in df_one_genre : 327438
#
# Occurences of each genre in df_one_genre :
#
#  genre
# ['Documentary']        99964
# ['Drama']              86533
# ['Comedy']             46779
# ['Animation']          22507
# ['Music']              18072
# ['Horror']             17628
# ['Thriller']            5649
# ['Action']              5421
# ['Romance']             5026
# ['Western']             4040
# ['Crime']               3133
# ['Family']              2891
# ['Science Fiction']     2663
# ['Fantasy']             1740
# ['Adventure']           1621
# ['Mystery']             1606
# ['History']              766
# ['War']                  762
# ['TV Movie']             637
# Name: count, dtype: int64

# %% [markdown]
# ### a) Loading and building training and validation dataset

# %%
SAMPLE_SIZE_2 = 5000
BATCH_SIZE_2 = 64
poster_dir = 'posters/'
AUTO = tf.data.experimental.AUTOTUNE

# %%
df_one_train = pd.read_csv("dataframe/training_set_one_genre.csv")
df_one_train = df_one_train.sample(int(SAMPLE_SIZE_2*0.8), random_state=42)
df_one_val = pd.read_csv("dataframe/validation_set_one_genre.csv")
df_one_val = df_one_val.sample(int(SAMPLE_SIZE_2*0.2), random_state=42)

# %%
print("Number of film in training set :", df_one_train.shape[0], "\n")
print("Number of film in validation set :", df_one_val.shape[0], "\n")
print("sum : ", df_one_train.shape[0]+df_one_val.shape[0], "\n")
print(df_one_train.head())
# Out:
# Number of film in training set : 4000
#
# Number of film in validation set : 1000
#
# sum :  5000
#
#            filename       genre
# 162323  1868192.jpg   ['Drama']
# 76775   1580757.jpg   ['Music']
# 11699   1363676.jpg   ['Drama']
# 188905  1684876.jpg   ['Drama']
# 152216  1154007.jpg  ['Comedy']

# %%
genre_Number = 19
global genre_Number
ds_train_1 = get_dataset(poster_dir, df_one_train, BATCH_SIZE_2)
ds_val_1 = get_dataset(poster_dir, df_one_val, BATCH_SIZE_2)

# %% [markdown]
# ### b) Creating and training the MCC model

# %% [markdown]
# In this second part we need to create a new model, which is almost the same than the previous one but this time we use the softmax activation function for the output layer, since now we can only have one right labels.

# %%
class MCCModel:

    def __init__(self, input_shape=(256, 256, 3), num_classes=19, dropout_rate=0.3, seed=40):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.dropout_rate = dropout_rate
        self.seed = seed
        self.model = self.build_model()


    def build_model(self):

        model = Sequential()

        model.add(Conv2D(filters=16, kernel_size=(3, 3), strides=(1, 1), input_shape=self.input_shape))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(2, 2))

        model.add(Conv2D(32, (3, 3)))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(2, 2))

        model.add(Conv2D(64, (3, 3)))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(MaxPooling2D(2, 2))

        model.add(Flatten())
        model.add(Dropout(rate=self.dropout_rate, seed=self.seed))

        model.add(Dense(64))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(rate=self.dropout_rate, seed=self.seed))

        model.add(Dense(32))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
        model.add(Dropout(rate=self.dropout_rate, seed=self.seed))

        model.add(Dense(self.num_classes, activation='softmax'))

        return model


    def get_model(self):
        return self.model

# %%
mcc_2 = MCCModel()
model_2 = mcc_2.get_model()

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[tf.keras.metrics.CategoricalAccuracy()])
model_2.summary()
#steps_per_epoch = sample_size//BATCH_SIZE
hist_2 = model_2.fit(ds_train_1, epochs=2, validation_data=ds_val_1, callbacks = [early_stopping])
#model_2.save(f'model/mcc_model_adam_ss=5000_epoch=4.keras')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 254, 254, 16)      448
#
#  batch_normalization_5 (Bat  (None, 254, 254, 16)      64
#  chNormalization)
#
#  activation_5 (Activation)   (None, 254, 254, 16)      0
#
#  max_pooling2d_3 (MaxPoolin  (None, 127, 127, 16)      0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 125, 125, 32)      4640
#
#  batch_normalization_6 (Bat  (None, 125, 125, 32)      128
#  chNormalization)
#
#  activation_6 (Activation)   (None, 125, 125, 32)      0
#
#  max_pooling2d_4 (MaxPoolin  (None, 62, 62, 32)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 60, 60, 64)        18496
#
#  batch_normalization_7 (Bat  (None, 60, 60, 64)        256
#  chNormalization)
#
#  activation_7 (Activation)   (None, 60, 60, 64)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 57600)             0
#
#  dropout_3 (Dropout)         (None, 57600)             0
#
#  dense_3 (Dense)             (None, 64)                3686464
#
#  batch_normalization_8 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_8 (Activation)   (None, 64)                0
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  batch_normalization_9 (Bat  (None, 32)                128
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32)                0
#
#  dropout_5 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 19)                627
#
# =================================================================
# Total params: 3713587 (14.17 MB)
# Trainable params: 3713171 (14.16 MB)
# Non-trainable params: 416 (1.62 KB)
# _________________________________________________________________
# Epoch 1/2
# 62/62 [==============================] - 677s 11s/step - loss: 2.7090 - categorical_accuracy: 0.2102 - val_loss: 2.3360 - val_categorical_accuracy: 0.2854
# Epoch 2/2
# 62/62 [==============================] - 633s 10s/step - loss: 2.2095 - categorical_accuracy: 0.3173 - val_loss: 2.1715 - val_categorical_accuracy: 0.2844

# %%
plot_train_and_val_loss(hist_2)

# %% [markdown]
# ### c) Evaluation of the MCC model

# %%
#model_1 = load_model('model/mcc_model_adam_ss=5000_epoch=4.keras')

# %%
df_one_test = pd.read_csv("dataframe/test_set_one_genre.csv")
df_one_test = df_one_test.sample(int(SAMPLE_SIZE_2*0.8), random_state=42)

# %%
ds_test_1 = get_dataset(poster_dir, df_one_test, BATCH_SIZE_2)

# %%
model_2.evaluate(ds_test_1)

# %%
proba_2 = model_2.predict(ds_test_1)
y_hat_m2 = np.argmax(proba_2, axis=1)
print(proba_2[0])
print(y_hat_m2[0])

# %%
y_true_one_hot = np.concatenate([y for x, y in ds_test_1], axis=0)
y_true = np.argmax(y_true_one_hot, axis=1)

# %%
with open('genre_to_index.json', 'r') as json_file:
            GTI = json.load(json_file)
index_to_genre = {v: k for k, v in GTI.items()}

# %%
y_pred_genres = [index_to_genre[idx] for idx in y_hat_m2]
y_true_genres = [index_to_genre[idx] for idx in y_true]

comparison_df_2 = pd.DataFrame({
    'true_genre': y_true_genres,
    'predict_genre': y_pred_genres
})

# %%
print(comparison_df_2.head(20))
# Out:
#      true_genre predict_genre
# 0        Comedy   Documentary
# 1   Documentary   Documentary
# 2   Documentary   Documentary
# 3   Documentary   Documentary
# 4        Horror   Documentary
# 5        Comedy         Drama
# 6         Music   Documentary
# 7     Adventure   Documentary
# 8       Western   Documentary
# 9         Drama   Documentary
# 10  Documentary   Documentary
# 11       Comedy   Documentary
# 12  Documentary   Documentary
# 13       Horror   Documentary
# 14  Documentary   Documentary
# 15      Romance   Documentary
# 16        Music   Documentary
# 17    Animation   Documentary
# 18        Drama   Documentary
# 19        Drama   Documentary

# %% [markdown]
# In view of these results, we can quickly deduce that our algorithm simply predicts the 2 most represented genres of our dataset. We therefore need to balance it.

# %% [markdown]
# # IV- Multi-class Classification (MCC) with reduced number of class

# %% [markdown]
# Finally, in this last section, we will further reduce the set of films considered in the hope of obtaining better results. More precisely, in addition of keeping only films associated to one genre, we also decide to reduce the number of genders from which our model must choose. So looking at the df_one_genre dataset, we have chosen to keep the 6 most represented genres in this dataset, namely : Documentary, Drama, Comedy, Animation, Music, and Horror.
# Moreover, we will balanced the number of films associated to each genre by limiting the number of film associated to the most reprensented genre. Let's see some statistics about this dataset.

# %%
df_genre_select = pd.read_csv("dataframe/df_genres_selected.csv")
print("Numbers of film in df_genre_select :", df_genre_select.shape[0],'\n')
print("Occurences of each genre in df_genre_select : \n\n", df_genre_select['genre'].value_counts(), "\n")
print("How our dataset looks like : \n\n", df_genre_select.head(10), "\n")

# %% [markdown]
# ### a) Loading and building training and validation dataset

# %%
SAMPLE_SIZE_3 = 5000
BATCH_SIZE_3 = 64
poster_dir = 'posters/'
AUTO = tf.data.experimental.AUTOTUNE

# %%
df_select_train = pd.read_csv("dataframe/training_set_genres_selected.csv")
df_select_train = df_select_train.sample(int(SAMPLE_SIZE_3*0.8), random_state=42)
df_select_val = pd.read_csv("dataframe/validation_set_genres_selected.csv")
df_select_val = df_select_val.sample(int(SAMPLE_SIZE_3*0.2), random_state=42)

# %%
print("Number of film in training set :", df_select_train.shape[0], "\n")
print("Number of film in validation set :", df_select_val.shape[0], "\n")
print("sum : ", df_select_train.shape[0]+df_select_val.shape[0], "\n")

# %%
genre_Number = 6
global genre_Number
ds_train_select = get_dataset(poster_dir, df_select_train, BATCH_SIZE_3)
ds_val_select = get_dataset(poster_dir, df_select_val, BATCH_SIZE_3)

# %% [markdown]
# ### b) Creating and training the MCC model

# %% [markdown]
# We create a new instance of the MCCModel class, this time specifying num_classes=6.

# %%
mcc_3 = MCCModel(num_classes=6)
model_3 = mcc_3.get_model()

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[tf.keras.metrics.CategoricalAccuracy()])
model_3.summary()
hist_3 = model_3.fit(ds_train_select, epochs=2, validation_data=ds_val_select, callbacks = [early_stopping])
#model_3.save('model/mcc_model_balanced6_adam_ss=10000_epoch=6.keras')

# %%
plot_train_and_val_loss(hist_3)

# %% [markdown]
# ### c) Evaluation of the MCC model

# %%
#from tensorflow.keras.models import load_model
#model_3 = load_model('model/mcc_model_balanced6_adam_ss=10000_epoch=6.keras')

# %%
df_select_test = pd.read_csv("dataframe/test_set_genres_selected.csv")
df_select_test = df_select_test.sample(int(SAMPLE_SIZE_3*0.8), random_state=42)

# %%
print(df_select_test.head())

# %%
ds_test_select = get_dataset(poster_dir, df_select_test, BATCH_SIZE_3)

# %%
model_3.evaluate(ds_test_select)

# %%
proba_m3 = model_3.predict(ds_test_select)
y_hat_m3 = np.argmax(proba_m3, axis=1)
print(proba_m3[0])
print(y_hat_m3[0])

# %%
y_true_one_hot_m3 = np.concatenate([y for x, y in ds_test_select], axis=0)
y_true_m3 = np.argmax(y_true_one_hot_m3, axis=1)

# %%
with open('genre_to_index_selected.json', 'r') as json_file:
            GTI = json.load(json_file)
index_to_genre_sel = {v: k for k, v in GTI.items()}

# %%
y_pred_genres_m3 = [index_to_genre_sel[idx] for idx in y_hat_m3]
y_true_genres_m3 = [index_to_genre_sel[idx] for idx in y_true_m3]

comparison_df_selected = pd.DataFrame({
    'true_genre': y_true_genres_m3,
    'predict_genre': y_pred_genres_m3
})

# %%
print(comparison_df_selected.head(20))
